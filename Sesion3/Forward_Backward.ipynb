# %% [markdown]
# ## Código

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

#
# A continuación se genera una muestra de 200 datos, con
# cuatro variables independientes, pero solo una explicativa
#
from sklearn.datasets import make_regression

np.random.seed(12345)

X, d = make_regression(
    n_samples=200,
    n_features=4,
    n_informative=1,
    bias=0.0,  # intercepto
    effective_rank=None,  # numero de vectores singulares para explicar los datos
    tail_strength=0.9,  # ? importancia relativa de las colas
    noise=12.0,
    shuffle=False,  # ?
    coef=False,  # ?coeficientes de la regresion
    random_state=12136,
)

#
# Grafica de la variable dependiente contra
# la variable explicativa
#
plt.scatter(X[:, 0], d)
plt.show()

#
# A continuación se estima el modelo de regresión lineal
# con las 4 variables independientes
#
import statsmodels.api as sm

model = sm.OLS(d, X)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.958
# Method:                 Least Squares   F-statistic:                              1155.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   5.01e-135
# Time:                        19:22:06   Log-Likelihood:                         -790.65
# No. Observations:                 200   AIC:                                      1589.
# Df Residuals:                     196   BIC:                                      1603.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Forward

# %%
#
# Modelo que titne una sola variable X1
#
model = sm.OLS(d, X[:, 0])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              4679.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   3.31e-140
# Time:                        19:40:59   Log-Likelihood:                         -790.94
# No. Observations:                 200   AIC:                                      1584.
# Df Residuals:                     199   BIC:                                      1587.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que titne una sola variable X2
#
model = sm.OLS(d, X[:, 1])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.001
# Model:                            OLS   Adj. R-squared (uncentered):             -0.004
# Method:                 Least Squares   F-statistic:                             0.1664
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                       0.684
# Time:                        19:41:22   Log-Likelihood:                         -1110.8
# No. Observations:                 200   AIC:                                      2224.
# Df Residuals:                     199   BIC:                                      2227.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que titne una sola variable X3
#
model = sm.OLS(d, X[:, 2])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.011
# Model:                            OLS   Adj. R-squared (uncentered):              0.006
# Method:                 Least Squares   F-statistic:                              2.130
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                       0.146
# Time:                        19:52:20   Log-Likelihood:                         -1109.8
# No. Observations:                 200   AIC:                                      2222.
# Df Residuals:                     199   BIC:                                      2225.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que titne una sola variable X4
#
model = sm.OLS(d, X[:, 3])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.003
# Model:                            OLS   Adj. R-squared (uncentered):             -0.002
# Method:                 Least Squares   F-statistic:                             0.5827
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                       0.446
# Time:                        19:53:23   Log-Likelihood:                         -1110.6
# No. Observations:                 200   AIC:                                      2223.
# Df Residuals:                     199   BIC:                                      2226.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que tiene dos variables X1 y X2 
#
model = sm.OLS(d, X[:,[0,1]])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              2328.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   2.74e-138
# Time:                        21:02:08   Log-Likelihood:                         -790.90
# No. Observations:                 200   AIC:                                      1586.
# Df Residuals:                     198   BIC:                                      1592.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que tiene dos variables X1 y X3
#
model = sm.OLS(d, X[:,[0,2]])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              2332.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   2.35e-138
# Time:                        21:02:27   Log-Likelihood:                         -790.75
# No. Observations:                 200   AIC:                                      1585.
# Df Residuals:                     198   BIC:                                      1592.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que tiene dos variables X1 y X4
#
model = sm.OLS(d, X[:,[0,3]])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              2329.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   2.72e-138
# Time:                        21:02:59   Log-Likelihood:                         -790.90
# No. Observations:                 200   AIC:                                      1586.
# Df Residuals:                     198   BIC:                                      1592.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# El mejor AIC se obtiene con X0, al agregar variables no se obtiene mejora entonces el proceso se detiene

# %% [markdown]
# ##Backward

# %%
#
# Modelo que tiene todas las variables
#
model = sm.OLS(d, X)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.958
# Method:                 Least Squares   F-statistic:                              1155.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   5.01e-135
# Time:                        21:05:22   Log-Likelihood:                         -790.65
# No. Observations:                 200   AIC:                                      1589.
# Df Residuals:                     196   BIC:                                      1603.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que tiene todas las variables menos X0
#
model = sm.OLS(d, X[:, [1,2,3]])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.014
# Model:                            OLS   Adj. R-squared (uncentered):             -0.001
# Method:                 Least Squares   F-statistic:                             0.9200
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                       0.432
# Time:                        21:15:59   Log-Likelihood:                         -1109.5
# No. Observations:                 200   AIC:                                      2225.
# Df Residuals:                     197   BIC:                                      2235.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que tiene todas las variables menos X1
#
model = sm.OLS(d, X[:, [0,2,3]])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              1548.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   1.22e-136
# Time:                        21:16:16   Log-Likelihood:                         -790.70
# No. Observations:                 200   AIC:                                      1587.
# Df Residuals:                     197   BIC:                                      1597.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que tiene todas las variables menos X2
#
model = sm.OLS(d, X[:, [0,1,3]])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              1545.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   1.43e-136
# Time:                        21:16:35   Log-Likelihood:                         -790.86
# No. Observations:                 200   AIC:                                      1588.
# Df Residuals:                     197   BIC:                                      1598.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que tiene todas las variables menos X3
#
model = sm.OLS(d, X[:, [0,1,2]])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              1548.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   1.23e-136
# Time:                        21:16:53   Log-Likelihood:                         -790.70
# No. Observations:                 200   AIC:                                      1587.
# Df Residuals:                     197   BIC:                                      1597.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# Eliminando dos variables obtenemos el menor AIC, podemos escoger X1 o X3, en este caso escogeremos X3, ya haremos el mismo proceso.

# %%
#
# Modelo que tiene X0, X1 
#
model = sm.OLS(d, X[:, [0,1]])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              2328.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   2.74e-138
# Time:                        21:22:51   Log-Likelihood:                         -790.90
# No. Observations:                 200   AIC:                                      1586.
# Df Residuals:                     198   BIC:                                      1592.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que tiene X0, X2 
#
model = sm.OLS(d, X[:, [0,2]])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              2332.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   2.35e-138
# Time:                        21:23:05   Log-Likelihood:                         -790.75
# No. Observations:                 200   AIC:                                      1585.
# Df Residuals:                     198   BIC:                                      1592.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que tiene X1, X2 
#
model = sm.OLS(d, X[:, [1,2]])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.011
# Model:                            OLS   Adj. R-squared (uncentered):              0.001
# Method:                 Least Squares   F-statistic:                              1.127
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                       0.326
# Time:                        21:23:48   Log-Likelihood:                         -1109.7
# No. Observations:                 200   AIC:                                      2223.
# Df Residuals:                     198   BIC:                                      2230.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# Eliminamos la variable X1

# %%
#
# Modelo que tiene X1
#
model = sm.OLS(d, X[:, 1])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.001
# Model:                            OLS   Adj. R-squared (uncentered):             -0.004
# Method:                 Least Squares   F-statistic:                             0.1664
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                       0.684
# Time:                        21:25:15   Log-Likelihood:                         -1110.8
# No. Observations:                 200   AIC:                                      2224.
# Df Residuals:                     199   BIC:                                      2227.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
# Modelo que tiene X0
#
model = sm.OLS(d, X[:, 0])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              4679.
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):                   3.31e-140
# Time:                        21:25:27   Log-Likelihood:                         -790.94
# No. Observations:                 200   AIC:                                      1584.
# Df Residuals:                     199   BIC:                                      1587.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# Como era de esperarse se obtiene el mejor AIC con X0 y el proceso ha finalizado
